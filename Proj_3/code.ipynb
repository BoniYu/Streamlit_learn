# %%
# It has run so ne need to rerun it
# %pip install nba_api
# Out:
# Requirement already satisfied: nba_api in c:\users\user\onedrive\documents\lib\site-packages (1.11.4)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\onedrive\documents\lib\site-packages (from nba_api) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\user\onedrive\documents\lib\site-packages (from nba_api) (2.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\user\onedrive\documents\lib\site-packages (from nba_api) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\onedrive\documents\lib\site-packages (from pandas>=2.2.0->nba_api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\onedrive\documents\lib\site-packages (from pandas>=2.2.0->nba_api) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\onedrive\documents\lib\site-packages (from pandas>=2.2.0->nba_api) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\onedrive\documents\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\onedrive\documents\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\onedrive\documents\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\onedrive\documents\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\user\onedrive\documents\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nba_api) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nba_api.stats.endpoints import leaguedashplayerstats
import pandas as pd

pd.set_option('display.max_columns', None)  # so nothing gets truncated

stats = leaguedashplayerstats.LeagueDashPlayerStats(
    season="2022-23",
    per_mode_detailed='PerGame'
)
df = stats.get_data_frames()[0]

print("Shape:", df.shape)
print("\nColumns:\n", df.columns.tolist())
print("\nDtypes:\n", df.dtypes)
print("\nFirst 5 rows:\n", df.head())
# Out:
# Shape: (539, 67)
#
# Columns:
#  ['PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2', 'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK', 'TD3_RANK', 'WNBA_FANTASY_PTS_RANK', 'TEAM_COUNT']
#
# Dtypes:
#  PLAYER_ID                 int64
# PLAYER_NAME              object
# NICKNAME                 object
# TEAM_ID                   int64
# TEAM_ABBREVIATION        object
#                           ...
# NBA_FANTASY_PTS_RANK      int64
# DD2_RANK                  int64
# TD3_RANK                  int64
# WNBA_FANTASY_PTS_RANK     int64
# TEAM_COUNT                int64
# Length: 67, dtype: object
#
# First 5 rows:
#     PLAYER_ID    PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP  \
# 0    1630639    A.J. Lawson     A.J.  1610612742               DAL  22.0  15
# 1    1631260       AJ Green       AJ  1610612749               MIL  23.0  35
# 2    1631100     AJ Griffin       AJ  1610612737               ATL  19.0  72
# 3     203932   Aaron Gordon    Aaron  1610612743               DEN  27.0  68
# 4    1628988  Aaron Holiday    Aaron  1610612737               ATL  26.0  63
#
#     W   L  W_PCT   MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  \
# 0   5  10  0.333   7.2  1.5   2.9   0.500   0.7   1.7    0.400  0.1  0.5
# 1  27   8  0.771   9.9  1.5   3.6   0.424   1.3   3.0    0.419  0.1  0.1
# 2  34  38  0.472  19.5  3.4   7.4   0.465   1.4   3.6    0.390  0.6  0.7
# 3  45  23  0.662  30.2  6.3  11.2   0.564   0.9   2.5    0.347  2.8  4.6
# 4  32  31  0.508  13.4  1.5   3.5   0.418   0.6   1.4    0.409  0.4  0.5
#
#    FT_PCT  OREB  DREB  REB  AST  TOV  STL  BLK  BLKA   PF  PFD   PTS  \
# 0   0.250   0.4   1.0  1.4  0.1  0.2  0.1  0.0   0.2  0.7  0.4   3.7
# 1   1.000   0.2   1.1  1.3  0.6  0.3  0.2  0.0   0.0  0.9  0.1   4.4
# 2   0.894   0.5   1.6  2.1  1.0  0.6  0.6  0.2   0.3  1.2  0.6   8.9
# 3   0.608   2.4   4.1  6.6  3.0  1.4  0.8  0.8   1.0  1.9  3.6  16.3
# 4   0.844   0.4   0.8  1.2  1.4  0.6  0.6  0.2   0.3  1.3  0.8   3.9
#
#    PLUS_MINUS  NBA_FANTASY_PTS  DD2  TD3  WNBA_FANTASY_PTS  GP_RANK  W_RANK  \
# 0        -3.1              5.8    0    0               6.2      451     459
# 1        -0.7              7.1    0    0               7.9      379     238
# 2         0.9             14.6    0    0              14.9      102     149
# 3         7.6             31.8   11    0              29.8      133      35
# 4         0.3              9.2    0    0               8.6      189     178
#
#    L_RANK  W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  \
# 0     430         442       484       417       438          140        302
# 1     442          14       448       411       386          378        173
# 2      69         326       260       208       199          240        148
# 3     303          64       107        75       106           68        244
# 4     164         255       383       418       401          399        325
#
#    FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  OREB_RANK  \
# 0        328            85       491       428          509        373
# 1        216            52       499       508            1        487
# 2        166           117       365       403           61        327
# 3        244           259        72        48          455         24
# 4        359            66       416       434          129        378
#
#    DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 0        458       453       520       497       495       491        358
# 1        445       465       428       487       478       491        498
# 2        372       377       339       382       256       372        268
# 3         90        56       121       144       151        65         32
# 4        486       477       260       387       251       345        315
#
#    PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  \
# 0      475       457       429              462                   482
# 1      454       518       392              309                   455
# 2      394       422       217              169                   287
# 3      205        58        82                4                    77
# 4      377       356       415              212                   413
#
#    DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK  TEAM_COUNT
# 0       253        39                    466           2
# 1       253        39                    436           1
# 2       253        39                    273           1
# 3        56        39                     89           1
# 4       253        39                    416           1

# %%
df = df.fillna(0)
rank_cols = [c for c in df.columns if c.endswith('_RANK')]
df = df.drop(columns=rank_cols)

# %%
df.head()
# Out:
#    PLAYER_ID    PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP  \
# 0    1630639    A.J. Lawson     A.J.  1610612742               DAL  22.0  15
# 1    1631260       AJ Green       AJ  1610612749               MIL  23.0  35
# 2    1631100     AJ Griffin       AJ  1610612737               ATL  19.0  72
# 3     203932   Aaron Gordon    Aaron  1610612743               DEN  27.0  68
# 4    1628988  Aaron Holiday    Aaron  1610612737               ATL  26.0  63
#
#     W   L  W_PCT   MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  \
# 0   5  10  0.333   7.2  1.5   2.9   0.500   0.7   1.7    0.400  0.1  0.5
# 1  27   8  0.771   9.9  1.5   3.6   0.424   1.3   3.0    0.419  0.1  0.1
# 2  34  38  0.472  19.5  3.4   7.4   0.465   1.4   3.6    0.390  0.6  0.7
# 3  45  23  0.662  30.2  6.3  11.2   0.564   0.9   2.5    0.347  2.8  4.6
# 4  32  31  0.508  13.4  1.5   3.5   0.418   0.6   1.4    0.409  0.4  0.5
#
#    FT_PCT  OREB  DREB  REB  AST  TOV  STL  BLK  BLKA   PF  PFD   PTS  \
# 0   0.250   0.4   1.0  1.4  0.1  0.2  0.1  0.0   0.2  0.7  0.4   3.7
# 1   1.000   0.2   1.1  1.3  0.6  0.3  0.2  0.0   0.0  0.9  0.1   4.4
# 2   0.894   0.5   1.6  2.1  1.0  0.6  0.6  0.2   0.3  1.2  0.6   8.9
# 3   0.608   2.4   4.1  6.6  3.0  1.4  0.8  0.8   1.0  1.9  3.6  16.3
# 4   0.844   0.4   0.8  1.2  1.4  0.6  0.6  0.2   0.3  1.3  0.8   3.9
#
#    PLUS_MINUS  NBA_FANTASY_PTS  DD2  TD3  WNBA_FANTASY_PTS  TEAM_COUNT
# 0        -3.1              5.8    0    0               6.2           2
# 1        -0.7              7.1    0    0               7.9           1
# 2         0.9             14.6    0    0              14.9           1
# 3         7.6             31.8   11    0              29.8           1
# 4         0.3              9.2    0    0               8.6           1
